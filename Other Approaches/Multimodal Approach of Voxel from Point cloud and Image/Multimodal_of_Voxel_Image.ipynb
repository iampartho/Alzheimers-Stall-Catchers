# %% [markdown]
# # Mount Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Copy Files

# %%
import shutil
import os

os.makedirs('data', exist_ok=True)

####For PointCloud Files#####
shutil.copyfile('/content/drive/My Drive/AlzheimerStallCatcher3DConvPointCloud/point_cloud.zip' , './data/point_cloud.zip')
shutil.copyfile('/content/drive/My Drive/AlzheimerStallCatcher3DConvPointCloud/traintestlist.zip' , './data/traintestlist.zip')


# !unzip data/point_cloud.zip;
# !unzip data/traintestlist.zip;

os.remove("./data/point_cloud.zip")
os.remove('./data/traintestlist.zip')

shutil.move('./point_cloud', './data/point_cloud')
# Out:
# Archive:  data/point_cloud.zip
#    creating: point_cloud/
#   inflating: point_cloud/187558.h5
#   inflating: point_cloud/280599.h5
#   inflating: point_cloud/105452.h5
#   inflating: point_cloud/105668.h5
#   inflating: point_cloud/110123.h5
#   inflating: point_cloud/110210.h5
#   inflating: point_cloud/110488.h5
#   inflating: point_cloud/110498.h5
#   inflating: point_cloud/110544.h5
#   inflating: point_cloud/110787.h5
#   inflating: point_cloud/111150.h5
#   inflating: point_cloud/111350.h5
#   inflating: point_cloud/112237.h5
#   inflating: point_cloud/112324.h5
#   inflating: point_cloud/112532.h5
#   inflating: point_cloud/112558.h5
#   inflating: point_cloud/112736.h5
#   inflating: point_cloud/112804.h5
#   inflating: point_cloud/113202.h5
#   inflating: point_cloud/113351.h5
#   inflating: point_cloud/113382.h5
#   inflating: point_cloud/113389.h5
#   inflating: point_cloud/113850.h5
#   inflating: point_cloud/114732.h5
#   inflating: point_cloud/114843.h5
#   inflating: point_cloud/115374.h5
#   inflating: point_cloud/115946.h5
#   inflating: point_cloud/115956.h5
#   inflating: point_cloud/115974.h5
#   inflating: point_cloud/116242.h5
#   inflating: point_cloud/116889.h5
#   inflating: point_cloud/117054.h5
#   inflating: point_cloud/117221.h5
#   inflating: point_cloud/117793.h5
#   inflating: point_cloud/117903.h5
#   inflating: point_cloud/117990.h5
#   inflating: point_cloud/118197.h5
#   inflating: point_cloud/118199.h5
#   inflating: point_cloud/118271.h5
#   inflating: point_cloud/118410.h5
#   inflating: point_cloud/118794.h5
#   inflating: point_cloud/119148.h5
#   inflating: point_cloud/119473.h5
#   inflating: point_cloud/119593.h5
#   inflating: point_cloud/120200.h5
#   inflating: point_cloud/120238.h5
#   inflating: point_cloud/120318.h5
#   inflating: point_cloud/120399.h5
#   inflating: point_cloud/120548.h5
#   inflating: point_cloud/120695.h5
#   inflating: point_cloud/121059.h5
#   inflating: point_cloud/121061.h5
#   inflating: point_cloud/121306.h5
#   inflating: point_cloud/121331.h5
#   inflating: point_cloud/121575.h5
#   inflating: point_cloud/121676.h5
#   inflating: point_cloud/121877.h5
#   inflating: point_cloud/122311.h5
#   inflating: point_cloud/122669.h5
#   inflating: point_cloud/122893.h5
#   inflating: point_cloud/123158.h5
#   inflating: point_cloud/123612.h5
#   inflating: point_cloud/123910.h5
#   inflating: point_cloud/124474.h5
#   inflating: point_cloud/124828.h5
#   inflating: point_cloud/125098.h5
#   inflating: point_cloud/125124.h5
#   inflating: point_cloud/125277.h5
#   inflating: micro_frames_gray/667564/42.jpg
#   inflating: micro_frames_gray/667564/43.jpg
#   inflating: micro_frames_gray/667564/44.jpg
#   inflating: micro_frames_gray/667564/45.jpg
#   inflating: micro_frames_gray/667564/46.jpg
#   inflating: micro_frames_gray/667564/47.jpg
#   inflating: micro_frames_gray/667564/48.jpg
#   inflating: micro_frames_gray/667564/49.jpg
#   inflating: micro_frames_gray/667564/5.jpg
#   inflating: micro_frames_gray/667564/50.jpg
#   inflating: micro_frames_gray/667564/51.jpg
#   inflating: micro_frames_gray/667564/52.jpg
#   inflating: micro_frames_gray/667564/53.jpg
#   inflating: micro_frames_gray/667564/54.jpg
#   inflating: micro_frames_gray/667564/55.jpg
#   inflating: micro_frames_gray/667564/56.jpg
#   inflating: micro_frames_gray/667564/57.jpg
#   inflating: micro_frames_gray/667564/58.jpg
#   inflating: micro_frames_gray/667564/59.jpg
#   inflating: micro_frames_gray/667564/6.jpg
#   inflating: micro_frames_gray/667564/60.jpg
#   inflating: micro_frames_gray/667564/61.jpg
#   inflating: micro_frames_gray/667564/62.jpg
#   inflating: micro_frames_gray/667564/63.jpg
#   inflating: micro_frames_gray/667564/64.jpg
#   inflating: micro_frames_gray/667564/7.jpg
#   inflating: micro_frames_gray/667564/8.jpg
#   inflating: micro_frames_gray/667564/9.jpg
#    creating: micro_frames_gray/667597/
#  extracting: micro_frames_gray/667597/0.jpg
#  extracting: micro_frames_gray/667597/1.jpg
#  extracting: micro_frames_gray/667597/10.jpg
#  extracting: micro_frames_gray/667597/11.jpg
#  extracting: micro_frames_gray/667597/12.jpg
#  extracting: micro_frames_gray/667597/13.jpg
#  extracting: micro_frames_gray/667597/14.jpg
#  extracting: micro_frames_gray/667597/15.jpg
#  extracting: micro_frames_gray/667597/16.jpg
#  extracting: micro_frames_gray/667597/17.jpg
#  extracting: micro_frames_gray/667597/18.jpg
#  extracting: micro_frames_gray/667597/19.jpg
#  extracting: micro_frames_gray/667597/2.jpg
#  extracting: micro_frames_gray/667597/20.jpg
#  extracting: micro_frames_gray/667597/21.jpg
#  extracting: micro_frames_gray/667597/22.jpg
#  extracting: micro_frames_gray/667597/23.jpg
#  extracting: micro_frames_gray/667597/24.jpg
#  extracting: micro_frames_gray/667597/25.jpg
#  extracting: micro_frames_gray/667597/26.jpg
#  extracting: micro_frames_gray/667597/27.jpg
#  extracting: micro_frames_gray/667597/28.jpg
#  extracting: micro_frames_gray/667597/29.jpg
#  extracting: micro_frames_gray/667597/3.jpg
#  extracting: micro_frames_gray/667597/30.jpg
#  extracting: micro_frames_gray/667597/31.jpg
#  extracting: micro_frames_gray/667597/32.jpg
#  extracting: micro_frames_gray/667597/33.jpg
#  extracting: micro_frames_gray/667597/34.jpg
#  extracting: micro_frames_gray/667597/35.jpg
#  extracting: micro_frames_gray/667597/36.jpg
#  extracting: micro_frames_gray/667597/37.jpg
#  extracting: micro_frames_gray/667597/38.jpg
#  extracting: micro_frames_gray/667597/39.jpg
#  extracting: micro_frames_gray/667597/4.jpg
#  extracting: micro_frames_gray/667597/40.jpg
#  extracting: micro_frames_gray/667597/41.jpg
#  extracting: micro_frames_gray/667597/42.jpg
#  extracting: micro_frames_gray/667597/43.jpg
#  extracting: micro_frames_gray/667597/44.jpg
#  extracting: micro_frames_gray/667597/45.jpg
#  extracting: micro_frames_gray/667597/46.jpg
#  extracting: micro_frames_gray/667597/47.jpg
#  extracting: micro_frames_gray/667597/48.jpg
#  extracting: micro_frames_gray/667597/49.jpg
#  extracting: micro_frames_gray/667597/5.jpg
#  extracting: micro_frames_gray/667597/50.jpg
#  extracting: micro_frames_gray/667597/51.jpg
#  extracting: micro_frames_gray/667597/52.jpg
#  extracting: micro_frames_gray/667597/53.jpg
#  extracting: micro_frames_gray/667597/54.jpg
#  extracting: micro_frames_gray/667597/55.jpg
#  extracting: micro_frames_gray/667597/56.jpg
#  extracting: micro_frames_gray/667597/57.jpg
#  extracting: micro_frames_gray/667597/58.jpg
#  extracting: micro_frames_gray/667597/59.jpg
#  extracting: micro_frames_gray/667597/6.jpg
#  extracting: micro_frames_gray/667597/60.jpg
#  extracting: micro_frames_gray/667597/7.jpg
#  extracting: micro_frames_gray/667597/8.jpg
#  extracting: micro_frames_gray/667597/9.jpg
#    creating: micro_frames_gray/667946/
#  extracting: micro_frames_gray/667946/0.jpg
#  extracting: micro_frames_gray/667946/1.jpg
#  extracting: micro_frames_gray/667946/10.jpg
#  extracting: micro_frames_gray/667946/11.jpg
#  extracting: micro_frames_gray/667946/12.jpg
#  extracting: micro_frames_gray/667946/13.jpg
#  extracting: micro_frames_gray/667946/14.jpg
#  extracting: micro_frames_gray/667946/15.jpg
#  extracting: micro_frames_gray/667946/16.jpg
#  extracting: micro_frames_gray/667946/17.jpg
#  extracting: micro_frames_gray/667946/18.jpg
#  extracting: micro_frames_gray/667946/19.jpg
#  extracting: micro_frames_gray/667946/2.jpg
#  extracting: micro_frames_gray/667946/20.jpg
#  extracting: micro_frames_gray/667946/21.jpg
#  extracting: micro_frames_gray/667946/22.jpg
#  extracting: micro_frames_gray/667946/23.jpg
#  extracting: micro_frames_gray/667946/24.jpg
#  extracting: micro_frames_gray/667946/25.jpg
#  extracting: micro_frames_gray/667946/26.jpg
#  extracting: micro_frames_gray/667946/27.jpg
#  extracting: micro_frames_gray/667946/28.jpg
#  extracting: micro_frames_gray/667946/29.jpg
#  extracting: micro_frames_gray/667946/3.jpg
#  extracting: micro_frames_gray/667946/30.jpg
#  extracting: micro_frames_gray/667946/31.jpg
#  extracting: micro_frames_gray/667946/32.jpg
#  extracting: micro_frames_gray/667946/33.jpg
#  extracting: micro_frames_gray/667946/34.jpg
#  extracting: micro_frames_gray/667946/35.jpg
#  extracting: micro_frames_gray/667946/36.jpg
#  extracting: micro_frames_gray/667946/37.jpg
#  extracting: micro_frames_gray/667946/38.jpg
#  extracting: micro_frames_gray/667946/39.jpg
#  extracting: micro_frames_gray/667946/4.jpg
#  extracting: micro_frames_gray/667946/40.jpg
#  extracting: micro_frames_gray/667946/41.jpg
#  extracting: micro_frames_gray/667946/42.jpg
#  extracting: micro_frames_gray/667946/43.jpg
#  extracting: micro_frames_gray/667946/44.jpg
#  extracting: micro_frames_gray/667946/45.jpg
#  extracting: micro_frames_gray/667946/46.jpg
#  extracting: micro_frames_gray/667946/47.jpg
#  extracting: micro_frames_gray/667946/48.jpg
#  extracting: micro_frames_gray/667946/49.jpg
#  extracting: micro_frames_gray/667946/5.jpg
#  extracting: micro_frames_gray/667946/50.jpg
#  extracting: micro_frames_gray/667946/51.jpg
#  extracting: micro_frames_gray/667946/52.jpg
#  extracting: micro_frames_gray/667946/53.jpg
#  extracting: micro_frames_gray/667946/54.jpg
#  extracting: micro_frames_gray/667946/55.jpg
#  extracting: micro_frames_gray/667946/56.jpg
#  extracting: micro_frames_gray/667946/57.jpg
#  extracting: micro_frames_gray/667946/58.jpg
#  extracting: micro_frames_gray/667946/59.jpg
#  extracting: micro_frames_gray/667946/6.jpg
#  extracting: micro_frames_gray/667946/60.jpg
#  extracting: micro_frames_gray/667946/61.jpg
#  extracting: micro_frames_gray/667946/62.jpg
#  extracting: micro_frames_gray/667946/63.jpg
#  extracting: micro_frames_gray/667946/64.jpg
#  extracting: micro_frames_gray/667946/65.jpg
#  extracting: micro_frames_gray/667946/66.jpg
#  extracting: micro_frames_gray/667946/67.jpg
#  extracting: micro_frames_gray/667946/68.jpg
#  extracting: micro_frames_gray/667946/69.jpg
#  extracting: micro_frames_gray/667946/7.jpg
#  extracting: micro_frames_gray/667946/70.jpg
#  extracting: micro_frames_gray/667946/71.jpg
#  extracting: micro_frames_gray/667946/72.jpg
#  extracting: micro_frames_gray/667946/73.jpg
#  extracting: micro_frames_gray/667946/74.jpg
#  extracting: micro_frames_gray/667946/75.jpg
#  extracting: micro_frames_gray/667946/76.jpg
#  extracting: micro_frames_gray/667946/77.jpg
#  extracting: micro_frames_gray/667946/78.jpg
#  extracting: micro_frames_gray/667946/79.jpg
#  extracting: micro_frames_gray/667946/8.jpg
#  extracting: micro_frames_gray/667946/9.jpg
#    creating: micro_frames_gray/667969/
#  extracting: micro_frames_gray/667969/0.jpg
#  extracting: micro_frames_gray/667969/1.jpg
#  extracting: micro_frames_gray/667969/10.jpg
#  extracting: micro_frames_gray/667969/11.jpg
#  extracting: micro_frames_gray/667969/12.jpg
#  extracting: micro_frames_gray/667969/13.jpg
#  extracting: micro_frames_gray/667969/14.jpg
#  extracting: micro_frames_gray/667969/15.jpg
#  extracting: micro_frames_gray/667969/16.jpg
#  extracting: micro_frames_gray/667969/17.jpg
#  extracting: micro_frames_gray/667969/18.jpg
#  extracting: micro_frames_gray/667969/19.jpg
#  extracting: micro_frames_gray/667969/2.jpg
#  extracting: micro_frames_gray/667969/20.jpg
#  extracting: micro_frames_gray/667969/21.jpg
#  extracting: micro_frames_gray/667969/22.jpg
#  extracting: micro_frames_gray/667969/23.jpg
#  extracting: micro_frames_gray/667969/24.jpg
#  extracting: micro_frames_gray/667969/25.jpg
#  extracting: micro_frames_gray/667969/26.jpg
#  extracting: micro_frames_gray/667969/27.jpg
#  extracting: micro_frames_gray/667969/28.jpg
#  extracting: micro_frames_gray/667969/29.jpg
#  extracting: micro_frames_gray/667969/3.jpg
#  extracting: micro_frames_gray/667969/30.jpg
#  extracting: micro_frames_gray/667969/31.jpg
#  extracting: micro_frames_gray/667969/32.jpg
#  extracting: micro_frames_gray/667969/33.jpg
#  extracting: micro_frames_gray/667969/34.jpg
#  extracting: micro_frames_gray/667969/35.jpg
#  extracting: micro_frames_gray/667969/36.jpg
#  extracting: micro_frames_gray/667969/37.jpg
#  extracting: micro_frames_gray/667969/38.jpg
#  extracting: micro_frames_gray/667969/4.jpg
#  extracting: micro_frames_gray/667969/5.jpg
#  extracting: micro_frames_gray/667969/6.jpg
#  extracting: micro_frames_gray/667969/7.jpg
#  extracting: micro_frames_gray/667969/8.jpg
#  extracting: micro_frames_gray/667969/9.jpg
#    creating: micro_frames_gray/667974/
#  extracting: micro_frames_gray/667974/0.jpg
#  extracting: micro_frames_gray/667974/1.jpg
#  extracting: micro_frames_gray/667974/10.jpg
#  extracting: micro_frames_gray/667974/11.jpg
#  extracting: micro_frames_gray/667974/12.jpg
#  extracting: micro_frames_gray/667974/13.jpg
#  extracting: micro_frames_gray/667974/14.jpg
#  extracting: micro_frames_gray/667974/15.jpg
#  extracting: micro_frames_gray/667974/16.jpg
#  extracting: micro_frames_gray/667974/17.jpg
#  extracting: micro_frames_gray/667974/18.jpg
#  extracting: micro_frames_gray/667974/19.jpg
#  extracting: micro_frames_gray/667974/2.jpg
#  extracting: micro_frames_gray/667974/20.jpg
#  extracting: micro_frames_gray/667974/21.jpg
#  extracting: micro_frames_gray/667974/22.jpg
#  extracting: micro_frames_gray/667974/23.jpg
#  extracting: micro_frames_gray/667974/24.jpg
#  extracting: micro_frames_gray/667974/25.jpg
#  extracting: micro_frames_gray/667974/26.jpg
#  extracting: micro_frames_gray/667974/27.jpg
#  extracting: micro_frames_gray/667974/28.jpg
#  extracting: micro_frames_gray/667974/29.jpg
#  extracting: micro_frames_gray/667974/3.jpg
#  extracting: micro_frames_gray/667974/30.jpg
#  extracting: micro_frames_gray/667974/31.jpg
#  extracting: micro_frames_gray/667974/32.jpg
#  extracting: micro_frames_gray/667974/33.jpg
#  extracting: micro_frames_gray/667974/34.jpg
#  extracting: micro_frames_gray/667974/35.jpg
#  extracting: micro_frames_gray/667974/36.jpg
#  extracting: micro_frames_gray/667974/37.jpg
#  extracting: micro_frames_gray/667974/38.jpg
#  extracting: micro_frames_gray/667974/39.jpg
#  extracting: micro_frames_gray/667974/4.jpg
#  extracting: micro_frames_gray/667974/40.jpg
#  extracting: micro_frames_gray/667974/41.jpg
#  extracting: micro_frames_gray/667974/42.jpg
#  extracting: micro_frames_gray/667974/43.jpg
#  extracting: micro_frames_gray/667974/44.jpg
#  extracting: micro_frames_gray/667974/45.jpg
#  extracting: micro_frames_gray/667974/46.jpg
#  extracting: micro_frames_gray/667974/47.jpg
#  extracting: micro_frames_gray/667974/48.jpg
#  extracting: micro_frames_gray/670821/18.jpg
#  extracting: micro_frames_gray/670821/19.jpg
#  extracting: micro_frames_gray/670821/2.jpg
#  extracting: micro_frames_gray/670821/20.jpg
#  extracting: micro_frames_gray/670821/21.jpg
#  extracting: micro_frames_gray/670821/22.jpg
#   inflating: micro_frames_gray/670821/23.jpg
#   inflating: micro_frames_gray/670821/24.jpg
#   inflating: micro_frames_gray/670821/25.jpg
#   inflating: micro_frames_gray/670821/26.jpg
#  extracting: micro_frames_gray/670821/27.jpg
#  extracting: micro_frames_gray/670821/28.jpg
#  extracting: micro_frames_gray/670821/29.jpg
#  extracting: micro_frames_gray/670821/3.jpg
#  extracting: micro_frames_gray/670821/30.jpg
#  extracting: micro_frames_gray/670821/31.jpg
#  extracting: micro_frames_gray/670821/32.jpg
#  extracting: micro_frames_gray/670821/33.jpg
#  extracting: micro_frames_gray/670821/34.jpg
#  extracting: micro_frames_gray/670821/35.jpg
#  extracting: micro_frames_gray/670821/36.jpg
#  extracting: micro_frames_gray/670821/37.jpg
#  extracting: micro_frames_gray/670821/38.jpg
#  extracting: micro_frames_gray/670821/39.jpg
#  extracting: micro_frames_gray/670821/4.jpg
#  extracting: micro_frames_gray/670821/40.jpg
#  extracting: micro_frames_gray/670821/41.jpg
#  extracting: micro_frames_gray/670821/42.jpg
#  extracting: micro_frames_gray/670821/43.jpg
#  extracting: micro_frames_gray/670821/44.jpg
#  extracting: micro_frames_gray/670821/45.jpg
#  extracting: micro_frames_gray/670821/46.jpg
#  extracting: micro_frames_gray/670821/47.jpg
#  extracting: micro_frames_gray/670821/48.jpg
#  extracting: micro_frames_gray/670821/49.jpg
#  extracting: micro_frames_gray/670821/5.jpg
#  extracting: micro_frames_gray/670821/50.jpg
#  extracting: micro_frames_gray/670821/51.jpg
#  extracting: micro_frames_gray/670821/52.jpg
#  extracting: micro_frames_gray/670821/53.jpg
#  extracting: micro_frames_gray/670821/54.jpg
#  extracting: micro_frames_gray/670821/55.jpg
#  extracting: micro_frames_gray/670821/56.jpg
#  extracting: micro_frames_gray/670821/57.jpg
#  extracting: micro_frames_gray/670821/58.jpg
#  extracting: micro_frames_gray/670821/59.jpg
#  extracting: micro_frames_gray/670821/6.jpg
#  extracting: micro_frames_gray/670821/60.jpg
#  extracting: micro_frames_gray/670821/61.jpg
#  extracting: micro_frames_gray/670821/62.jpg
#  extracting: micro_frames_gray/670821/63.jpg
#  extracting: micro_frames_gray/670821/64.jpg
#  extracting: micro_frames_gray/670821/65.jpg
#  extracting: micro_frames_gray/670821/66.jpg
#  extracting: micro_frames_gray/670821/7.jpg
#  extracting: micro_frames_gray/670821/8.jpg
#  extracting: micro_frames_gray/670821/9.jpg
#    creating: micro_frames_gray/671044/
#  extracting: micro_frames_gray/671044/0.jpg
#  extracting: micro_frames_gray/671044/1.jpg
#  extracting: micro_frames_gray/671044/10.jpg
#  extracting: micro_frames_gray/671044/100.jpg
#  extracting: micro_frames_gray/671044/101.jpg
#  extracting: micro_frames_gray/671044/102.jpg
#  extracting: micro_frames_gray/671079/29.jpg
#  extracting: micro_frames_gray/671079/3.jpg
#  extracting: micro_frames_gray/671079/30.jpg
# ...
#  extracting: micro_frames_gray/684406/69.jpg
#  extracting: micro_frames_gray/684406/7.jpg
#  extracting: micro_frames_gray/684406/8.jpg
#  extracting: micro_frames_gray/684406/9.jpg
#    creating: micro_frames_gray/684435/
#  extracting: micro_frames_gray/684435/0.jpg
#  extracting: micro_frames_gray/684435/1.jpg
#  extracting: micro_frames_gray/684435/10.jpg
#  extracting: micro_frames_gray/684435/11.jpg
#  extracting: micro_frames_gray/684435/12.jpg
#  extracting: micro_frames_gray/684435/13.jpg
#  extracting: micro_frames_gray/684435/14.jpg
#  extracting: micro_frames_gray/684435/15.jpg
#  extracting: micro_frames_gray/684435/16.jpg
#  extracting: micro_frames_gray/684435/17.jpg
#  extracting: micro_frames_gray/684435/18.jpg
#  extracting: micro_frames_gray/684435/19.jpg
#  extracting: micro_frames_gray/684435/2.jpg
#  extracting: micro_frames_gray/684435/20.jpg
#  extracting: micro_frames_gray/684435/21.jpg
#  extracting: micro_frames_gray/684435/22.jpg
#  extracting: micro_frames_gray/684435/23.jpg
#  extracting: micro_frames_gray/684435/24.jpg
#  extracting: micro_frames_gray/684435/25.jpg
#  extracting: micro_frames_gray/684435/26.jpg
#  extracting: micro_frames_gray/684435/27.jpg
#  extracting: micro_frames_gray/684435/28.jpg
#  extracting: micro_frames_gray/684435/29.jpg
#  extracting: micro_frames_gray/684435/3.jpg
#  extracting: micro_frames_gray/684435/30.jpg
#  extracting: micro_frames_gray/684435/31.jpg
#  extracting: micro_frames_gray/684435/32.jpg
#  extracting: micro_frames_gray/684435/33.jpg
#  extracting: micro_frames_gray/684435/34.jpg
#  extracting: micro_frames_gray/684435/35.jpg
#  extracting: micro_frames_gray/684435/36.jpg
#  extracting: micro_frames_gray/684435/37.jpg
#  extracting: micro_frames_gray/684435/38.jpg
#  extracting: micro_frames_gray/684435/39.jpg
#  extracting: micro_frames_gray/684435/4.jpg
#  extracting: micro_frames_gray/684435/40.jpg
#  extracting: micro_frames_gray/684435/41.jpg
#  extracting: micro_frames_gray/684435/42.jpg
#  extracting: micro_frames_gray/684435/43.jpg
#  extracting: micro_frames_gray/684435/44.jpg
#  extracting: micro_frames_gray/684435/45.jpg
#  extracting: micro_frames_gray/684435/46.jpg
#  extracting: micro_frames_gray/684435/47.jpg
#  extracting: micro_frames_gray/684435/48.jpg
#  extracting: micro_frames_gray/684435/49.jpg
#  extracting: micro_frames_gray/684435/5.jpg
#  extracting: micro_frames_gray/684435/50.jpg
#  extracting: micro_frames_gray/684435/51.jpg
#  extracting: micro_frames_gray/684435/52.jpg
#  extracting: micro_frames_gray/684435/53.jpg
#  extracting: micro_frames_gray/684435/54.jpg
#  extracting: micro_frames_gray/684435/55.jpg
#  extracting: micro_frames_gray/684435/56.jpg
#  extracting: micro_frames_gray/684435/57.jpg
#  extracting: micro_frames_gray/684435/58.jpg
#  extracting: micro_frames_gray/684435/6.jpg
#  extracting: micro_frames_gray/684435/7.jpg
#  extracting: micro_frames_gray/684435/8.jpg
#  extracting: micro_frames_gray/684435/9.jpg
#    creating: micro_frames_gray/684600/
#  extracting: micro_frames_gray/684600/0.jpg
#  extracting: micro_frames_gray/684600/1.jpg
#  extracting: micro_frames_gray/684600/10.jpg
#  extracting: micro_frames_gray/684600/11.jpg
#  extracting: micro_frames_gray/684600/12.jpg
#  extracting: micro_frames_gray/684600/13.jpg
#  extracting: micro_frames_gray/684600/14.jpg
#  extracting: micro_frames_gray/684600/15.jpg
#  extracting: micro_frames_gray/684600/16.jpg
#  extracting: micro_frames_gray/684600/17.jpg
#  extracting: micro_frames_gray/684600/18.jpg
#  extracting: micro_frames_gray/684600/19.jpg
#  extracting: micro_frames_gray/684600/2.jpg
#  extracting: micro_frames_gray/684600/20.jpg
#  extracting: micro_frames_gray/684600/21.jpg
#  extracting: micro_frames_gray/684600/22.jpg
#  extracting: micro_frames_gray/684600/23.jpg
#  extracting: micro_frames_gray/684600/24.jpg
#  extracting: micro_frames_gray/684600/25.jpg
#  extracting: micro_frames_gray/684600/26.jpg
#  extracting: micro_frames_gray/684600/27.jpg
#  extracting: micro_frames_gray/684600/28.jpg
#  extracting: micro_frames_gray/684600/29.jpg
#  extracting: micro_frames_gray/684600/3.jpg
#  extracting: micro_frames_gray/684600/30.jpg
#  extracting: micro_frames_gray/684600/31.jpg
#  extracting: micro_frames_gray/684600/32.jpg
#  extracting: micro_frames_gray/684600/33.jpg
#  extracting: micro_frames_gray/684600/34.jpg
#  extracting: micro_frames_gray/684600/35.jpg
#  extracting: micro_frames_gray/684600/36.jpg
#  extracting: micro_frames_gray/684600/37.jpg
#  extracting: micro_frames_gray/684600/38.jpg
#  extracting: micro_frames_gray/684600/39.jpg
#  extracting: micro_frames_gray/684600/4.jpg
#  extracting: micro_frames_gray/684600/40.jpg
#  extracting: micro_frames_gray/684600/41.jpg
#  extracting: micro_frames_gray/684600/42.jpg
#  extracting: micro_frames_gray/684600/43.jpg
#  extracting: micro_frames_gray/684600/44.jpg
#  extracting: micro_frames_gray/684600/45.jpg
#  extracting: micro_frames_gray/684600/46.jpg
#  extracting: micro_frames_gray/684600/47.jpg
#  extracting: micro_frames_gray/684600/48.jpg
#  extracting: micro_frames_gray/684600/5.jpg
#  extracting: micro_frames_gray/684600/6.jpg
#  extracting: micro_frames_gray/684600/7.jpg
#  extracting: micro_frames_gray/684600/8.jpg
#  extracting: micro_frames_gray/684600/9.jpg
#    creating: micro_frames_gray/684744/
#  extracting: micro_frames_gray/684744/0.jpg
#  extracting: micro_frames_gray/684744/1.jpg
#  extracting: micro_frames_gray/684744/10.jpg
#  extracting: micro_frames_gray/684744/11.jpg
#  extracting: micro_frames_gray/684744/12.jpg
#  extracting: micro_frames_gray/684744/13.jpg
#  extracting: micro_frames_gray/684744/14.jpg
#  extracting: micro_frames_gray/684744/15.jpg
#  extracting: micro_frames_gray/684744/16.jpg
#  extracting: micro_frames_gray/684744/17.jpg
#  extracting: micro_frames_gray/684744/18.jpg
#  extracting: micro_frames_gray/684744/19.jpg
#  extracting: micro_frames_gray/684744/2.jpg
#  extracting: micro_frames_gray/684744/20.jpg
#  extracting: micro_frames_gray/684744/21.jpg
#  extracting: micro_frames_gray/684744/22.jpg
#  extracting: micro_frames_gray/684744/23.jpg
#  extracting: micro_frames_gray/684744/24.jpg
#  extracting: micro_frames_gray/684744/25.jpg
#  extracting: micro_frames_gray/684744/26.jpg
#  extracting: micro_frames_gray/684744/27.jpg
#  extracting: micro_frames_gray/684744/28.jpg
#  extracting: micro_frames_gray/684744/29.jpg
#  extracting: micro_frames_gray/684744/3.jpg
#  extracting: micro_frames_gray/684744/30.jpg
#  extracting: micro_frames_gray/684744/31.jpg
#  extracting: micro_frames_gray/684744/32.jpg
#  extracting: micro_frames_gray/684744/33.jpg
#  extracting: micro_frames_gray/684744/34.jpg
#  extracting: micro_frames_gray/684744/35.jpg
#  extracting: micro_frames_gray/684744/36.jpg
#  extracting: micro_frames_gray/684744/37.jpg
#  extracting: micro_frames_gray/684744/38.jpg
#  extracting: micro_frames_gray/684744/39.jpg
#  extracting: micro_frames_gray/684744/4.jpg
#  extracting: micro_frames_gray/684744/40.jpg
#  extracting: micro_frames_gray/684744/41.jpg
#  extracting: micro_frames_gray/684744/42.jpg
#  extracting: micro_frames_gray/684744/43.jpg
#  extracting: micro_frames_gray/684744/44.jpg
#  extracting: micro_frames_gray/684744/45.jpg
#  extracting: micro_frames_gray/684744/46.jpg
#  extracting: micro_frames_gray/684744/47.jpg
#  extracting: micro_frames_gray/684744/48.jpg
#  extracting: micro_frames_gray/684744/49.jpg
#  extracting: micro_frames_gray/684744/5.jpg
#  extracting: micro_frames_gray/684744/50.jpg
#  extracting: micro_frames_gray/684744/51.jpg
#  extracting: micro_frames_gray/684744/52.jpg
#  extracting: micro_frames_gray/684744/6.jpg
#  extracting: micro_frames_gray/684744/7.jpg
#  extracting: micro_frames_gray/684744/8.jpg
#  extracting: micro_frames_gray/684744/9.jpg
#    creating: micro_frames_gray/685597/
#  extracting: micro_frames_gray/685597/0.jpg
#  extracting: micro_frames_gray/685597/1.jpg
#  extracting: micro_frames_gray/685597/10.jpg
#  extracting: micro_frames_gray/685597/11.jpg
#  extracting: micro_frames_gray/685597/12.jpg
#  extracting: micro_frames_gray/685597/13.jpg
#  extracting: micro_frames_gray/685597/14.jpg
#  extracting: micro_frames_gray/685597/15.jpg
#  extracting: micro_frames_gray/685597/16.jpg
#  extracting: micro_frames_gray/685597/17.jpg
#  extracting: micro_frames_gray/685597/18.jpg
#  extracting: micro_frames_gray/685597/19.jpg
#  extracting: micro_frames_gray/685597/2.jpg
#  extracting: micro_frames_gray/685597/20.jpg
#  extracting: micro_frames_gray/685597/21.jpg
#  extracting: micro_frames_gray/685597/22.jpg
#  extracting: micro_frames_gray/685597/23.jpg
#  extracting: micro_frames_gray/685597/24.jpg
#  extracting: micro_frames_gray/685597/25.jpg
#  extracting: micro_frames_gray/685597/26.jpg
#  extracting: micro_frames_gray/685597/27.jpg
#  extracting: micro_frames_gray/685597/28.jpg
#  extracting: micro_frames_gray/685597/29.jpg
#  extracting: micro_frames_gray/685597/3.jpg
#  extracting: micro_frames_gray/685597/30.jpg
#  extracting: micro_frames_gray/685597/31.jpg
#  extracting: micro_frames_gray/685597/32.jpg
#  extracting: micro_frames_gray/685597/33.jpg
#  extracting: micro_frames_gray/685597/34.jpg
#  extracting: micro_frames_gray/685597/35.jpg
#  extracting: micro_frames_gray/685597/36.jpg
#  extracting: micro_frames_gray/685597/37.jpg
#  extracting: micro_frames_gray/685597/38.jpg
#  extracting: micro_frames_gray/685597/39.jpg
#  extracting: micro_frames_gray/685597/4.jpg
#  extracting: micro_frames_gray/685597/40.jpg
#  extracting: micro_frames_gray/685597/41.jpg
#  extracting: micro_frames_gray/685597/42.jpg
#  extracting: micro_frames_gray/685597/43.jpg
#  extracting: micro_frames_gray/685597/44.jpg
#  extracting: micro_frames_gray/685597/45.jpg
#  extracting: micro_frames_gray/685597/46.jpg
#  extracting: micro_frames_gray/685597/47.jpg
#  extracting: micro_frames_gray/685597/5.jpg
#  extracting: micro_frames_gray/685597/6.jpg
#  extracting: micro_frames_gray/685597/7.jpg
#  extracting: micro_frames_gray/685597/8.jpg
#  extracting: micro_frames_gray/685597/9.jpg
#    creating: micro_frames_gray/685640/
#  extracting: micro_frames_gray/685640/0.jpg
#  extracting: micro_frames_gray/685640/1.jpg
#  extracting: micro_frames_gray/685640/10.jpg
#  extracting: micro_frames_gray/685640/11.jpg
#  extracting: micro_frames_gray/685640/12.jpg
#  extracting: micro_frames_gray/685640/13.jpg
#  extracting: micro_frames_gray/685640/14.jpg
#  extracting: micro_frames_gray/685640/15.jpg
#  extracting: micro_frames_gray/685640/16.jpg
#  extracting: micro_frames_gray/685640/17.jpg
#  extracting: micro_frames_gray/685640/18.jpg
#  extracting: micro_frames_gray/685640/19.jpg
#  extracting: micro_frames_gray/685640/2.jpg
#  extracting: micro_frames_gray/685640/20.jpg
#  extracting: micro_frames_gray/685640/21.jpg
#  extracting: micro_frames_gray/685640/22.jpg
#  extracting: micro_frames_gray/685640/23.jpg
#  extracting: micro_frames_gray/685640/24.jpg
#  extracting: micro_frames_gray/685640/25.jpg
#  extracting: micro_frames_gray/685640/26.jpg
#  extracting: micro_frames_gray/685640/27.jpg
#  extracting: micro_frames_gray/685640/28.jpg
#  extracting: micro_frames_gray/685640/29.jpg
#  extracting: micro_frames_gray/685640/3.jpg
#  extracting: micro_frames_gray/685640/30.jpg
#  extracting: micro_frames_gray/685640/31.jpg
#  extracting: micro_frames_gray/685640/32.jpg
#  extracting: micro_frames_gray/685640/33.jpg
#  extracting: micro_frames_gray/685640/34.jpg
#  extracting: micro_frames_gray/685640/35.jpg
#  extracting: micro_frames_gray/685640/36.jpg
#  extracting: micro_frames_gray/685640/37.jpg
#  extracting: micro_frames_gray/685640/38.jpg
#  extracting: micro_frames_gray/685640/39.jpg
#  extracting: micro_frames_gray/685640/4.jpg
#  extracting: micro_frames_gray/685640/40.jpg
#  extracting: micro_frames_gray/685640/41.jpg
#  extracting: micro_frames_gray/685640/42.jpg
#  extracting: micro_frames_gray/685640/43.jpg
#  extracting: micro_frames_gray/685640/44.jpg
#  extracting: micro_frames_gray/685640/45.jpg
#  extracting: micro_frames_gray/685640/46.jpg
#  extracting: micro_frames_gray/685640/47.jpg
#  extracting: micro_frames_gray/685640/48.jpg
#  extracting: micro_frames_gray/685640/49.jpg
#  extracting: micro_frames_gray/685640/5.jpg
#  extracting: micro_frames_gray/685640/50.jpg
#  extracting: micro_frames_gray/685640/51.jpg
#  extracting: micro_frames_gray/685640/52.jpg
#  extracting: micro_frames_gray/685640/53.jpg
#  extracting: micro_frames_gray/685640/54.jpg
#  extracting: micro_frames_gray/685640/55.jpg
#  extracting: micro_frames_gray/685640/56.jpg
#  extracting: micro_frames_gray/685640/57.jpg
#  extracting: micro_frames_gray/685640/6.jpg
#  extracting: micro_frames_gray/685640/7.jpg
#  extracting: micro_frames_gray/685640/8.jpg
#  extracting: micro_frames_gray/685640/9.jpg
#    creating: micro_frames_gray/686290/
#  extracting: micro_frames_gray/686290/0.jpg
#  extracting: micro_frames_gray/686290/1.jpg
#  extracting: micro_frames_gray/686290/10.jpg
#  extracting: micro_frames_gray/686290/11.jpg
#  extracting: micro_frames_gray/686290/12.jpg
#  extracting: micro_frames_gray/686290/13.jpg
#  extracting: micro_frames_gray/686290/14.jpg
#  extracting: micro_frames_gray/686290/15.jpg
#  extracting: micro_frames_gray/686290/16.jpg
#  extracting: micro_frames_gray/686290/17.jpg
#  extracting: micro_frames_gray/686290/18.jpg
#  extracting: micro_frames_gray/686290/19.jpg
#  extracting: micro_frames_gray/686290/2.jpg
#  extracting: micro_frames_gray/686290/20.jpg
#  extracting: micro_frames_gray/686290/21.jpg
#  extracting: micro_frames_gray/686290/22.jpg
#  extracting: micro_frames_gray/686290/23.jpg
#  extracting: micro_frames_gray/686290/24.jpg
#  extracting: micro_frames_gray/686290/25.jpg
#  extracting: micro_frames_gray/686290/26.jpg
#  extracting: micro_frames_gray/686290/27.jpg
#  extracting: micro_frames_gray/686290/28.jpg
#  extracting: micro_frames_gray/686290/29.jpg
#  extracting: micro_frames_gray/686290/3.jpg
#  extracting: micro_frames_gray/686290/30.jpg
#  extracting: micro_frames_gray/686290/31.jpg
#  extracting: micro_frames_gray/686290/32.jpg
#  extracting: micro_frames_gray/686290/33.jpg
#  extracting: micro_frames_gray/686290/34.jpg
#  extracting: micro_frames_gray/686290/35.jpg
#  extracting: micro_frames_gray/686290/36.jpg
#  extracting: micro_frames_gray/686290/37.jpg
#  extracting: micro_frames_gray/686290/38.jpg
#  extracting: micro_frames_gray/686290/39.jpg
#  extracting: micro_frames_gray/686290/4.jpg
#  extracting: micro_frames_gray/686290/40.jpg
#  extracting: micro_frames_gray/686290/41.jpg
#  extracting: micro_frames_gray/686290/42.jpg
#  extracting: micro_frames_gray/686290/43.jpg
#  extracting: micro_frames_gray/686290/44.jpg
#  extracting: micro_frames_gray/686290/45.jpg
#  extracting: micro_frames_gray/686290/46.jpg
#  extracting: micro_frames_gray/686290/47.jpg
#  extracting: micro_frames_gray/686290/48.jpg
#  extracting: micro_frames_gray/686290/49.jpg
#  extracting: micro_frames_gray/686290/5.jpg
#  extracting: micro_frames_gray/686290/50.jpg
#  extracting: micro_frames_gray/686290/51.jpg
#  extracting: micro_frames_gray/686290/52.jpg
#  extracting: micro_frames_gray/686290/53.jpg
#  extracting: micro_frames_gray/686290/54.jpg
#  extracting: micro_frames_gray/686290/55.jpg
#  extracting: micro_frames_gray/686290/56.jpg
#  extracting: micro_frames_gray/686290/57.jpg
#  extracting: micro_frames_gray/686290/58.jpg
#  extracting: micro_frames_gray/686290/59.jpg
#  extracting: micro_frames_gray/686290/6.jpg
#  extracting: micro_frames_gray/686290/60.jpg
#  extracting: micro_frames_gray/686290/61.jpg
#  extracting: micro_frames_gray/686290/62.jpg
#  extracting: micro_frames_gray/686290/63.jpg
#  extracting: micro_frames_gray/686290/64.jpg
#  extracting: micro_frames_gray/686290/7.jpg
#  extracting: micro_frames_gray/686290/8.jpg
#  extracting: micro_frames_gray/686290/9.jpg
# './data/micro_frames'

# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
from tqdm import tqdm
import os
import glob
import gc

from sklearn.metrics import matthews_corrcoef as mcc

# PyTorch libraries and modules
import torch
from torch.autograd import Variable
import torch.nn as nn
import torch.utils.data


torch.manual_seed(100)


from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import itertools
import datetime

# %% [markdown]
# # Balanced Batch Sampler

# %%
import torchvision
import torch.utils.data
import random


class BalancedBatchSampler(torch.utils.data.sampler.Sampler):
    def __init__(self, dataset):
        self.dataset = {}
        self.balanced_max = 0
        # Save all the indices for all the classes
        for idx in range(0, len(dataset)):
            label = self._get_label(dataset, idx)
            if label not in self.dataset:
                self.dataset[label] = []
            self.dataset[label].append(idx)
            self.balanced_max = len(self.dataset[label]) \
                if len(self.dataset[label]) > self.balanced_max else self.balanced_max
        
        # Oversample the classes with fewer elements than the max
        for label in self.dataset:
            while len(self.dataset[label]) < self.balanced_max:
                self.dataset[label].append(random.choice(self.dataset[label]))
    
        self.keys = list(self.dataset.keys())
        self.currentkey = 0

    def __iter__(self):
        while len(self.dataset[self.keys[self.currentkey]]) > 0:
            yield self.dataset[self.keys[self.currentkey]].pop()
            self.currentkey = (self.currentkey + 1) % len(self.keys)

    
    def _get_label(self, dataset, idx):
        dataset_type = type(dataset)
        if dataset_type is torchvision.datasets.MNIST:
            return dataset.train_labels[idx].item()
        elif dataset_type is torchvision.datasets.ImageFolder:
            return dataset.imgs[idx][1]
        else:
            (image_sequence, target) = dataset.__getitem__(idx)
            return target

    def __len__(self):
        return self.balanced_max*len(self.keys)

# %%
# Some data

batch_size = 32

split_number = 1
#num_epochs = 50

# %% [markdown]
# # **Dataset for PointCloud-Voxel**

# %% [markdown]
# ### Voxel Dataset Class

# %%
import h5py
import os
import numpy as np
import torch
from torch.utils.data import Dataset, DataLoader
import pandas as pd

class VoxelDataset(Dataset):
    def __init__(self, dataset_path, split_path, split_number, input_shape, training):
        self.training = training
        self.sequences, self.labels = self._extract_sequence_paths_and_labels(dataset_path, split_path, split_number,
                                                                              training)  # creating a list of directories where the extracted frames are saved
        self.label_names = ["Non-stalled", "Stalled"]  # Getting the label names or name of the class
        self.num_classes = len(self.label_names)  # Getting the number of class
        self.input_shape = input_shape

    def _extract_sequence_paths_and_labels(
            self, dataset_path, split_path="data/traintestlist", split_number=0, training=True
    ):
        """ Extracts paths to sequences given the specified train / test split """
        fn = f"fold_{split_number}_train.csv" if training else f"fold_{split_number}_test.csv"
        split_path = os.path.join(split_path, fn)
        df = pd.read_csv(split_path)
        file_name = df['filename'].values
        all_labels = df['class'].values
        sequence_paths = []
        classes = []
        for i, video_name in enumerate(file_name):
            seq_name = video_name.split(".mp4")[0]
            sequence_paths += [os.path.join(dataset_path, seq_name).replace('\\', '/')]
            classes += [all_labels[i]]
        return sequence_paths, classes

    def pc2voxel(self, cloud0, cloud1, cloud2, depth=32, height=64, width=64):

        voxel_grid = np.zeros((3, depth, height, width), dtype=np.float16)

        in_depth = max(np.max(cloud0[:, 0]), np.max(cloud1[:, 0]), np.max(cloud2[:, 0]))
        in_height = max(np.max(cloud0[:, 1]), np.max(cloud1[:, 1]), np.max(cloud2[:, 1]))
        in_width = max(np.max(cloud0[:, 2]), np.max(cloud1[:, 2]), np.max(cloud2[:, 2]))

        if in_depth >= depth:
            depth_ratio = depth / (in_depth + 1)
            cloud0[:, 0] = np.uint32(cloud0[:, 0].astype(float) * depth_ratio)
            cloud1[:, 0] = np.uint32(cloud1[:, 0].astype(float) * depth_ratio)
            cloud2[:, 0] = np.uint32(cloud2[:, 0].astype(float) * depth_ratio)
        if in_height >= height:
            height_ratio = height / (in_height + 1)
            cloud0[:, 1] = np.uint32(cloud0[:, 1].astype(float) * height_ratio)
            cloud1[:, 1] = np.uint32(cloud1[:, 1].astype(float) * height_ratio)
            cloud2[:, 1] = np.uint32(cloud2[:, 1].astype(float) * height_ratio)
        if in_width >= width:
            width_ratio = width / (in_width + 1)
            cloud0[:, 2] = np.uint32(cloud0[:, 2].astype(float) * width_ratio)
            cloud1[:, 2] = np.uint32(cloud1[:, 2].astype(float) * width_ratio)
            cloud2[:, 2] = np.uint32(cloud2[:, 2].astype(float) * width_ratio)

        voxel_grid[0, cloud0[:, 0], cloud0[:, 1], cloud0[:, 2]] = 1.0
        voxel_grid[1, cloud1[:, 0], cloud1[:, 1], cloud1[:, 2]] = 1.0
        voxel_grid[2, cloud2[:, 0], cloud2[:, 1], cloud2[:, 2]] = 1.0

        return voxel_grid

    def get_cloud(self, filename):
        depth = self.input_shape[0]
        height = self.input_shape[1]
        width = self.input_shape[2]

        hf = h5py.File(filename, 'r')
        c1 = hf['cloud1'][:]
        c2 = hf['cloud2'][:]
        c3 = hf['cloud3'][:]
        hf.close()

        X = self.pc2voxel(c1, c2, c3, depth=depth, height=height, width=width)
        X = torch.from_numpy(X).float()
        return X

    def __len__(self):
        return len(self.sequences)

    def __getitem__(self, index):
        sequence_path = self.sequences[index % len(self)]
        target = self.labels[index % len(self)]

        voxels = self.get_cloud(sequence_path + ".h5")

        return voxels, target

# %% [markdown]
# ### Create Train and Test Datasets of Pt Cloud

# %%
import gc
import time

start = time.time()

dataset_path = 'data/point_cloud'
split_path = 'traintestlist'

checkpoint_model = ''

voxel_shape = [32, 64, 64]


# Define training set
train_dataset_vox = VoxelDataset(
    dataset_path=dataset_path,
    split_path=split_path,
    split_number=split_number,
    input_shape=voxel_shape,
    training=True,
)
train_dataloader_vox = DataLoader(train_dataset_vox, batch_size= batch_size,sampler=BalancedBatchSampler(train_dataset_vox),shuffle=False, num_workers=4)
# Define test set
test_dataset_vox = VoxelDataset(
    dataset_path=dataset_path,
    split_path=split_path,
    split_number=split_number,
    input_shape=voxel_shape,
    training=False,
)
#test_dataloader_vox = DataLoader(test_dataset_vox, sampler=BalancedBatchSampler(test_dataset_vox), batch_size=batch_size, shuffle=False, num_workers=4)
test_dataloader_vox = DataLoader(test_dataset_vox, batch_size=batch_size, shuffle=False, num_workers=4)

endtime = time.time()

print("Elapsed time : " + str(endtime-start))

gc.collect()
# Out:
# Elapsed time : 5.681003093719482
# 24

# %% [markdown]
# # **Dataset for Images**

# %% [markdown]
# ### Image Dataset Class

# %%
import glob
import random
import os
import numpy as np
import torch
import pandas as pd

from torch.utils.data import Dataset, DataLoader
from PIL import Image
import torchvision.transforms as transforms


class ImageDataset(Dataset):
    def __init__(self, dataset_path, split_path, split_number, input_shape, sequence_length, training):
        self.training = training
        self.sequences, self.labels = self._extract_sequence_paths_and_labels(dataset_path, split_path, split_number,
                                                                              training)  # creating a list of directories where the extracted frames are saved
        self.sequence_length = int(
            sequence_length)  # Defining how many frames should be taken per video for training and testing
        self.label_names = ["Non-stalled", "Stalled"]  # Getting the label names or name of the class
        self.num_classes = len(self.label_names)  # Getting the number of class
        self.input_shape = input_shape
        self.transform = transforms.Compose(
            [
                transforms.Grayscale(num_output_channels=3),
                transforms.Resize(input_shape[-2:], Image.BICUBIC),
                transforms.ToTensor(),
                transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
            ]
        )  # This is to transform the datasets to same sizes, it's basically resizing -> converting the image to Tensor image -> then normalizing the image -> composing all the transformation in a single image

    def _extract_sequence_paths_and_labels(
            self, dataset_path, split_path="data/traintestlist", split_number=0, training=True
    ):
        """ Extracts paths to sequences given the specified train / test split """
        fn = f"fold_{split_number}_train.csv" if training else f"fold_{split_number}_test.csv"
        split_path = os.path.join(split_path, fn)
        df = pd.read_csv(split_path)
        file_name = df['filename'].values
        all_labels = df['class'].values
        sequence_paths = []
        classes = []
        for i, video_name in enumerate(file_name):
            seq_name = video_name.split(".mp4")[0]
            sequence_paths += [os.path.join(dataset_path, seq_name).replace('\\', '/')]
            classes += [all_labels[i]]
        return sequence_paths, classes

    def _frame_number(self, image_path):
        """ Extracts frame number from filepath """
        image_path = image_path.replace('\\', '/')
        try:
            return int(image_path.split('/')[-1].split('.jpg')[0])
        except:
            print("Got error while getting image number ....")
            exit()

    def _pad_to_length(self, sequence, path):
        """ Pads the video frames to the required sequence length for small videos"""
        try:
            left_pad = sequence[0]
        except:
            print("Got error while padding ....")
            exit()
        if self.sequence_length is not None:
            while len(sequence) < self.sequence_length:
                sequence.insert(0, left_pad)
        return sequence

    def __getitem__(self, index):
        sequence_path = self.sequences[index % len(self)]
        target = self.labels[index % len(self)]
        # Sort frame sequence based on frame number 
        image_paths = sorted(glob.glob(sequence_path + '/*.jpg'), key=lambda path: self._frame_number(path))

        # Pad frames of videos shorter than `self.sequence_length` to length

        image_paths = self._pad_to_length(image_paths, sequence_path)
        total_image = len(image_paths)
        if total_image >= self.sequence_length and total_image < (
                self.sequence_length + int(self.sequence_length // 2)):
            midpoint = (total_image // 2)
            sample_interval = 1
            start_i = (midpoint - (self.sequence_length // 2))
            end_i = start_i + self.sequence_length
        elif total_image >= (self.sequence_length + int(self.sequence_length // 2)):
            midpoint = (total_image // 2)
            sample_interval = 1
            start_i = (midpoint - (self.sequence_length // 2) + int((self.sequence_length // 2) // 2)) - 1
            end_i = start_i + self.sequence_length
        else:
            start_i = 0
            end_i = total_image
            sample_interval = 1
        # flip = np.random.random() < 0.5
        # Extract frames as tensors
        image_sequence = []
        for i in range(start_i, end_i, sample_interval):
            if self.sequence_length is None or len(image_sequence) < self.sequence_length:
                img = Image.open(image_paths[i])
                image_tensor = self.transform(img)
                # if flip:
                #     image_tensor = torch.flip(image_tensor, (-1,))
                image_sequence.append(image_tensor)
        image_sequence = torch.stack(image_sequence)
        image_sequence = image_sequence.view(3, self.sequence_length, self.input_shape[-2], self.input_shape[-2])
        return image_sequence, target

    def __len__(self):
        return len(self.sequences)

# %% [markdown]
# ### Create Train and Test Datasets of Images

# %%
import gc
import time


start = time.time()

dataset_path = 'data/micro_frames'
split_path = 'traintestlist'
sequence_length=40
img_dim = 112
channels = 3
latent_dim = 512
checkpoint_model = ''

image_shape = (channels, img_dim, img_dim)


# Define training set
train_dataset_img = ImageDataset(
    dataset_path=dataset_path,
    split_path=split_path,
    sequence_length=sequence_length,
    split_number=split_number,
    input_shape=image_shape,
    training=True,
)
train_dataloader_img = DataLoader(train_dataset_img, batch_size= batch_size,sampler=BalancedBatchSampler(train_dataset_img),shuffle=False, num_workers=4)

# Define test set
test_dataset_img = ImageDataset(
    dataset_path=dataset_path,
    split_path=split_path,
    split_number=split_number,
    sequence_length=sequence_length,
    input_shape=image_shape,
    training=False,
)

test_dataloader_img = DataLoader(test_dataset_img, batch_size=batch_size, shuffle=False, num_workers=4)

endtime = time.time()

print("Elapsed time : " + str(endtime-start))

gc.collect()
# Out:
# Elapsed time : 66.65416693687439
# 0

# %%
#length should be same for image and voxel data
print(f"Length of image loader {len(train_dataloader_img)}, Length of pt cld loader {len(train_dataloader_vox)}")
print(f"Length of test image loader {len(test_dataloader_img)}, Length of test pt cld loader {len(test_dataloader_vox)}")
# Out:
# Length of image loader 80, Length of pt cld loader 80
# Length of test image loader 19, Length of test pt cld loader 19

# %% [markdown]
# # **Multimodal Model**

# %%
import torch.nn as nn
import torch.nn.functional as F
from torchvision.models.video import r2plus1d_18
from torchvision.models.video import r3d_18

import os
import sys



##############################
#     Encoder for Image
##############################

class Encoder(nn.Module):
    def __init__(self, latent_dim):
        super(Encoder, self).__init__()
        resnet = r2plus1d_18(pretrained=True)
        self.dropout1 = nn.Dropout(0.2)
        self.feature_extractor = nn.Sequential(*list(resnet.children())[0:3])
        self.feature_extractor_new1 = nn.Sequential(*list(resnet.children())[3:4])
        self.feature_extractor_new2 = nn.Sequential(*list(resnet.children())[4:5])
        self.feature_extractor_new3 = nn.Sequential(*list(resnet.children())[5:6])
        self.final = nn.Sequential(
            nn.Dropout(0.5),
            nn.Linear(resnet.fc.in_features, latent_dim),
            nn.BatchNorm1d(latent_dim, momentum=0.01)
        )
    

    def forward(self, x):
        with torch.no_grad():
           x = self.feature_extractor(x)
        x = self.dropout1(x)  
        x = self.feature_extractor_new1(x)
        x = self.dropout1(x)
        x = self.feature_extractor_new2(x)
        x = self.dropout1(x)
        x = self.feature_extractor_new3(x)
        x = x.view(x.size(0), -1)
        #print(self.final(x))
        
        return self.final(x)


##############################
#   Encoder For Point Cloud
##############################

class Encoder_pt(nn.Module):
    def __init__(self, latent_dim):
        super(Encoder_pt, self).__init__()
        self.feature_extractor_pt = r3d_18(pretrained = True)
        self.final_pt = nn.Sequential(
            nn.Dropout(0.5),
            nn.Linear(self.feature_extractor_pt.fc.out_features, latent_dim),
            nn.BatchNorm1d(latent_dim, momentum=0.01)
        )
    

    def forward(self, x):
        #with torch.no_grad():
        x = self.feature_extractor_pt(x)
        x = x.view(x.size(0), -1)

        return self.final_pt(x)


##############################
#      MultiModal Model
##############################

#dim=-1 is the right most dimension

class Multimodal(nn.Module):
    def __init__(
        self, num_classes, latent_dim=512, hidden_dim=1024
    ):
        super(Multimodal, self).__init__()
        self.encoder = Encoder(latent_dim)
        self.encoder_pt = Encoder_pt(latent_dim)
        hidden_dim2 = int(hidden_dim/2)      #if hidden_dim = 512 then dense layers : 1024->512->256->1
        hidden_dim3 = int(hidden_dim2/4)
        hidden_dim4 = int(hidden_dim3/4)
        hidden_dim5 = int(hidden_dim4/4)
        self.output_layers_final = nn.Sequential(
            nn.Linear(1024, hidden_dim),
            nn.BatchNorm1d(hidden_dim, momentum=0.01),
            nn.ReLU(),
            nn.Dropout(0.4),
            nn.Linear(hidden_dim, hidden_dim2),
            nn.BatchNorm1d(hidden_dim2, momentum=0.01),
            nn.ReLU(),
            nn.Dropout(0.4),
            nn.Linear(hidden_dim2, 2),
            #nn.Sigmoid()
        )


    ##Concatenating two stream
    
    def forward(self, x, y):
        
        x = self.encoder(x)
        y = self.encoder_pt(y)
        #print(f"img tensor size {x.shape} and pt tensor size {y.shape}")
        x = torch.cat((x, y), 1)
        #print(f"concatenated size is {x.shape}")
        return self.output_layers_final(x)

# %% [markdown]
# # **Model Parameters for Image model**

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Classification criterion
#cls_criterion = nn.BCEWithLogitsLoss().to(device)
cls_criterion = nn.CrossEntropyLoss().to(device) 

# Define network
model_img = Multimodal(
    num_classes=2,
    latent_dim=latent_dim,
    hidden_dim=512
)

model_img = model_img.to(device)

#for half precision

model_img.half()  
for layer in model_img.modules():
  if isinstance(layer, nn.BatchNorm2d):
    layer.float()

# Add weights from checkpoint model if specified
if checkpoint_model:
    model_img.load_state_dict(torch.load(checkpoint_model))

learning_rate = 2e-4

optimizer = torch.optim.Adam(model_img.parameters(), lr= learning_rate, eps=1e-04, weight_decay=1e-04)

step_size = 11
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size, gamma=0.75, last_epoch=-1)

# %% [markdown]
# # Confusion Function

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
from sklearn.utils.multiclass import unique_labels
from sklearn.metrics import matthews_corrcoef as mcc


MCC_SCORE = 0


def plot_confusion_matrix(y_true, y_pred, classes,
                          normalize=False,
                          title=None,
                          cmap=plt.cm.RdYlGn):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if not title:
        if normalize:
            title = 'Normalized confusion matrix'
        else:
            title = 'Confusion matrix, without normalization'

    # Compute confusion matrix
    cm = confusion_matrix(y_true, y_pred)
    # Only use the labels that appear in the data
    classes = classes[unique_labels(y_true, y_pred)]

    del(y_pred)
    del(y_true)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    fig, ax = plt.subplots(figsize=(12, 12))
    im = ax.imshow(cm, interpolation='nearest', cmap=cmap)
    ax.figure.colorbar(im, ax=ax)
    # We want to show all ticks...
    ax.set(xticks=np.arange(cm.shape[1]),
           yticks=np.arange(cm.shape[0]),
           # ... and label them with the respective list entries
           xticklabels=classes, yticklabels=classes,
           title=title,
           ylabel='True label',
           xlabel='Predicted label')

    # Rotate the tick labels and set their alignment.
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
             rotation_mode="anchor")

    # Loop over data dimensions and create text annotations.
    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], fmt),
                    ha="center", va="center",
                    color="white" if cm[i, j] > thresh else "black")
    fig.tight_layout()
    return ax

# %%
def test_model(epoch):
    """ Evaluate the model on the test set """
    print("")
    #defining numpy array to store the true labels and predicted labels
    y_true = np.array([])
    y_pred = np.array([])

    # Preparing the model for evaluation
    model_img.eval()
    test_metrics = {"loss": [], "acc": []}
    for batch_i, ((X1, y), (X2,y2)) in enumerate(zip(test_dataloader_img, test_dataloader_vox)):
        image_sequences = Variable(X1.to(device), requires_grad=False)
        pt_cloud = Variable(X2.to(device), requires_grad=False)

        #print(f"From image loader {y} and pt loader {y2}")  
        #print(f"From image loader {y} and pt loader {y2}")
      
        labels = Variable(y.to(device), requires_grad=False)
        
        
        image_sequences = image_sequences.half()
        pt_cloud = pt_cloud.half()
        
        # Get sequence predictions
        
        y_true = np.append(y_true, labels.cpu().numpy())
        
        with torch.no_grad():
            # Get sequence predictions
            predictions = model_img(image_sequences, pt_cloud)

            predicted = torch.max(predictions.data, 1)[1]   

            y_pred = np.append(y_pred, predicted.cpu().numpy())
        
        # Compute metrics
        acc = 100 * (predicted == labels).cpu().numpy().mean()
        
        #for bcewithlogits loss
        #acc = 100 * (acc.detach() == labels).cpu().numpy().mean()
        #labels = labels.view(-1,1)
        
        loss =   cls_criterion(predictions, labels).item()
        
        # Keep track of loss and accuracy
        test_metrics["loss"].append(loss)
        test_metrics["acc"].append(acc)
        
        # Log test performance
        sys.stdout.write(
            "\rTesting -- [Batch %d/%d] [Loss: %f (%f), Acc: %.2f%% (%.2f%%)]"
            % (
                batch_i,
                len(test_dataloader_img),
                loss,
                np.mean(test_metrics["loss"]),
                acc,
                np.mean(test_metrics["acc"]),
            )
        )
        
    
    final_acc=round(np.mean(test_metrics["acc"]),3)


    # Save model checkpoint
    
    # Using the learning rate scheduler while monitoring Loss and printing the learning rate after every epoch
    for param_group in optimizer.param_groups:
        print("\nCurrent Learning Rate is : " + str(param_group['lr']))
    
    model_img.train()
    print("")
    # Getting the MCC score for evaluation and plotting the confusion matrix and saving that matrix
    mcc_score = round(mcc(y_true.astype(int), y_pred.astype(int)), 5)

    print(f"MCC score : {mcc_score}")
    mcc_score_str = "MCC Score: " + str(mcc_score) + "\n\n"

    plot_title = mcc_score_str + "Confusion matrix, Without Normalization\n"

    
    class_names = ['Non-stalled', 'Stalled']
    class_names = np.array(class_names)
    plot_confusion_matrix(y_true.astype(int), y_pred.astype(int), classes=class_names, title=plot_title)

    # Save model checkpoint
    global MCC_SCORE

    if MCC_SCORE < mcc_score or int(epoch) % 2 == 0:
        if MCC_SCORE < mcc_score:
            MCC_SCORE = mcc_score
        os.makedirs("model_checkpoints", exist_ok=True)
        torch.save(model_img.state_dict(), f"model_checkpoints/Multimodal_catcrosent_spl1_epoch_{epoch}_acc_{final_acc}_mcc_{mcc_score}.pth")

    os.makedirs("confusion_matrix", exist_ok=True)
    plt.savefig(f"confusion_matrix/epoch{epoch}with_accuracy{final_acc}_mcc_{mcc_score}.png")

# %% [markdown]
# # **Multimodal Training**

# %%
num_epochs = 60
for epoch in range(num_epochs):
        epoch_metrics = {"loss": [], "acc": []}
        prev_time = time.time()
        print(f"--- Epoch {epoch}---")
        for batch_i, ((X1, y), (X2,y2)) in enumerate(zip(train_dataloader_img, train_dataloader_vox)):
            if X1.size(0) == 1:
                continue
            image_sequences = Variable(X1.to(device), requires_grad=True)
            pt_cloud = Variable(X2.to(device), requires_grad=True)

             
            #print(f"From image loader {y} and pt loader {y2}")
            
            labels = Variable(y.to(device), requires_grad=False)
            
            image_sequences = image_sequences.half()
            pt_cloud = pt_cloud.half()
            
            optimizer.zero_grad()
            
            # Get sequence predictions
            predictions = model_img(image_sequences, pt_cloud)
            
            
            
            predicted = torch.max(predictions.data, 1)[1]   
            acc = 100 * (predicted == labels).cpu().numpy().mean()
            
            #for bcewithlogits loss
            #acc = torch.tensor([0 if i<=0.5 else 1 for i in predictions]).to(device)
            #acc = 100 * (acc.detach() == labels).cpu().numpy().mean()
            # Compute metrics
            #labels = labels.view(-1, 1)
            
            loss = cls_criterion.forward(predictions, labels)
            
            loss.backward()
            optimizer.step()

            # Keep track of epoch metrics
            epoch_metrics["loss"].append(loss.item())
            epoch_metrics["acc"].append(acc)

            # Determine approximate time left
            batches_done = epoch * len(train_dataloader_img) + batch_i
            batches_left = num_epochs * len(train_dataloader_img) - batches_done
            time_left = datetime.timedelta(seconds=batches_left * (time.time() - prev_time))
            prev_time = time.time()

            # Print log
            sys.stdout.write(
                "\r[Epoch %d/%d] [Batch %d/%d] [Loss: %f (%f), Acc: %.2f%% (%.2f%%)] ETA: %s"
                % (
                    epoch,
                    num_epochs,
                    batch_i,
                    len(train_dataloader_img),
                    loss.item(),
                    np.mean(epoch_metrics["loss"]),
                    acc,
                    np.mean(epoch_metrics["acc"]),
                    time_left,
                )
            )
            #deleting variable to free up memory
            del(X1)
            del(y)
            del(X2)
            del(y2)
            del(image_sequences)
            del(pt_cloud)
            del(labels)
            del(predictions)
            del(loss)


            # Empty cache
            if torch.cuda.is_available():
                torch.cuda.empty_cache()

        # Evaluate the model on the test set
        test_model(epoch)
        
        train_dataloader_img = DataLoader(train_dataset_img, batch_size= batch_size,sampler=BalancedBatchSampler(train_dataset_img),shuffle=False, num_workers=4)
        train_dataloader_vox = DataLoader(train_dataset_vox, batch_size= batch_size,sampler=BalancedBatchSampler(train_dataset_vox),shuffle=False, num_workers=4)
        
        scheduler.step()
# Out:
# --- Epoch 0---
# [Epoch 0/60] [Batch 79/80] [Loss: 0.434082 (0.641791), Acc: 75.00% (65.59%)] ETA: 4:19:14.456103
# Testing -- [Batch 18/19] [Loss: 0.491943 (0.556923), Acc: 75.00% (73.68%)]
# Current Learning Rate is : 0.0002
#
# MCC score : 0.38822
# Confusion matrix, without normalization
# [[334  89]
#  [ 69 108]]
# --- Epoch 1---
# [Epoch 1/60] [Batch 79/80] [Loss: 0.382080 (0.479572), Acc: 83.33% (77.84%)] ETA: 4:16:19.279858
# Testing -- [Batch 18/19] [Loss: 0.532715 (0.705348), Acc: 83.33% (69.19%)]
# Current Learning Rate is : 0.0002
#
# MCC score : 0.4723
# Confusion matrix, without normalization
# [[251 172]
#  [ 14 163]]
# --- Epoch 2---
# [Epoch 2/60] [Batch 5/80] [Loss: 0.322021 (0.421692), Acc: 87.50% (80.73%)] ETA: 11:09:14.571379
